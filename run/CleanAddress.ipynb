# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv('../assets/Customer.csv')

# %%
city_counts = df['city'].value_counts()

# Display the result
print(city_counts)
# Out:
# city
# Hồ Chí Minh                            1352
# TP Hồ Chí Minh                          753
# Thành phố Hồ Chí Minh                   668
# Hà Nội                                  571
# Bình Dương                              437
#                                        ...
# 1                                         1
# Q. Bình Tân                               1
# 10                                        1
# Quãng Nam                                 1
# Quận Gò Vấp, Thành phố Hồ Chí Minh.       1
# Name: count, Length: 198, dtype: int64

# %%
import pandas as pd
import json

# Load the JSON data (assuming you have a JSON file)
with open('../assets/arrVietnam.json', 'r', encoding='utf-8') as f:
    arr_vietnam = json.load(f)

# Extract the 'value' field from each object and push to a list
value_list = [item['value'] for item in arr_vietnam]

# Print the result
print(value_list)
# Out:
# ['Thành phố Hà Nội', 'Tỉnh Hà Giang', 'Tỉnh Cao Bằng', 'Tỉnh Bắc Kạn', 'Tỉnh Tuyên Quang', 'Tỉnh Lào Cai', 'Tỉnh Điện Biên', 'Tỉnh Lai Châu', 'Tỉnh Sơn La', 'Tỉnh Yên Bái', 'Tỉnh Hoà Bình', 'Tỉnh Thái Nguyên', 'Tỉnh Lạng Sơn', 'Tỉnh Quảng Ninh', 'Tỉnh Bắc Giang', 'Tỉnh Phú Thọ', 'Tỉnh Vĩnh Phúc', 'Tỉnh Bắc Ninh', 'Tỉnh Hải Dương', 'Thành phố Hải Phòng', 'Tỉnh Hưng Yên', 'Tỉnh Thái Bình', 'Tỉnh Hà Nam', 'Tỉnh Nam Định', 'Tỉnh Ninh Bình', 'Tỉnh Thanh Hóa', 'Tỉnh Nghệ An', 'Tỉnh Hà Tĩnh', 'Tỉnh Quảng Bình', 'Tỉnh Quảng Trị', 'Tỉnh Thừa Thiên Huế', 'Thành phố Đà Nẵng', 'Tỉnh Quảng Nam', 'Tỉnh Quảng Ngãi', 'Tỉnh Bình Định', 'Tỉnh Phú Yên', 'Tỉnh Khánh Hòa', 'Tỉnh Ninh Thuận', 'Tỉnh Bình Thuận', 'Tỉnh Kon Tum', 'Tỉnh Gia Lai', 'Tỉnh Đắk Lắk', 'Tỉnh Đắk Nông', 'Tỉnh Lâm Đồng', 'Tỉnh Bình Phước', 'Tỉnh Tây Ninh', 'Tỉnh Bình Dương', 'Tỉnh Đồng Nai', 'Tỉnh Bà Rịa - Vũng Tàu', 'Thành phố Hồ Chí Minh', 'Tỉnh Long An', 'Tỉnh Tiền Giang', 'Tỉnh Bến Tre', 'Tỉnh Trà Vinh', 'Tỉnh Vĩnh Long', 'Tỉnh Đồ
# ...

# %%
# Convert value_list to a DataFrame
df_values = pd.DataFrame(value_list, columns=['City Values'])

# Define the output file path
output_file_path = '../assets/Value_List.xlsx'

# Export the DataFrame to Excel
df_values.to_excel(output_file_path, index=False, sheet_name='Values', engine='openpyxl')

# Print a message indicating the file has been saved
print(f"Value list exported to {output_file_path}")
# Out:
# Value list exported to ../assets/Value_List.xlsx

# %%
# Iterate over each value in value_list
for value in value_list:
    # Check whether the current value from value_list is present as a substring in each cell of the "city" column, ignoring case
    mask = df['city'].str.contains(value, na=False, case=False)

    # Replace the matching cells with the value (case-insensitive)
    df.loc[mask, 'city'] = value

# Display the updated DataFrame
print(df)
# Out:
#           id  preferredContactMethod  \
# 0          1                     NaN
# 1          2                     NaN
# 2          3                     NaN
# 3          4                     NaN
# 4          5                     NaN
# ...      ...                     ...
# 10698  11833                     NaN
# 10699  11834                     NaN
# 10700  11835                     NaN
# 10701  11836                     NaN
# 10702  11837                     NaN
#
#                                                  address  \
# 0      175/2 Song Hành , KP 6 , P Tân Hưng Thuận, Q12...
# 1      15/7 Đường số 21, Phường 8, Gò Vấp, Thành phố ...
# 2      12 Đ. Huỳnh Văn Nghệ, Phường 15, Tân Bình, T...
# 3      11 Phan Huy Ích, Phường 14, Gò Vấp, Thành phố ...
# 4      1028 Tân Kỳ Tân Quý, Bình Hưng Hoà A, Bình Tân...
# ...                                                  ...
# 10698  Thôn Phước Lợi, Xã Phước Đồng, Thành phố Nha T...
# ...

# %%
# Define the output file path
output_file_path = '../assets/Updated_Customer.xlsx'

# Export the DataFrame to Excel
df.to_excel(output_file_path, index=False, sheet_name='Customers', engine='openpyxl')

# Print a message indicating the file has been saved
print(f"DataFrame exported to {output_file_path}")
# Out:
# DataFrame exported to ../assets/Updated_Customer.xlsx

# %%
# Steps:
# Read the XLSX file.
# Group by the "city" column.
# Collect distinct groups into a list.
# Export the result to a new XLSX file.
import pandas as pd

# Step 1: Read the CSV file into a pandas DataFrame
input_file = '../assets/city.csv'  # Replace with your file path
df = pd.read_csv(input_file)  # Change to pd.read_csv for CSV input

# Step 2: Get distinct groups by 'city' column
distinct_cities = df['city'].unique()  # Get unique cities
distinct_cities_df = pd.DataFrame(distinct_cities, columns=['city'])  # Create a DataFrame

# Step 3: Export the distinct cities to a new XLSX file
output_file = '../assets/grouped_by_city.xlsx'  # Output file path
distinct_cities_df.to_excel(output_file, index=False)

print("Exported successfully to:", output_file)
# Out:
# Exported successfully to: ../assets/grouped_by_city.xlsx

# %%
import pandas as pd

# Step 1: Read the XLSX file into a pandas DataFrame
input_file = "../assets/customerWithCity.csv"  # Replace with your file path
df = pd.read_csv(input_file)

# Step 2: Replace values in the 'city' column
df["city"] = df["city"].replace(
    {
        "An Giang": "Tỉnh An Giang",
        "An giang": "Tỉnh An Giang",
        "BRVT": "Tỉnh Bà Rịa - Vũng Tàu",
        "Bà Rịa Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Bà Rịa Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Vũng tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Bà Rịa - Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Bà Rịa-Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Tỉnh Bà Rịa - Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "Bà Rịa - Vũng Tàu": "Tỉnh Bà Rịa - Vũng Tàu",
        "VT": "Tỉnh Bà Rịa - Vũng Tàu",
        "BRVT": "Tỉnh Bà Rịa - Vũng Tàu",
        "Biên Hòa, Đồng Nai": "Tỉnh Đồng Nai",
        "Đồng Nai": "Tỉnh Đồng Nai",
        "Tx. Long Khánh, ĐN": "Tỉnh Đồng Nai",
        "H. Trảng Bom, ĐN": "Tỉnh Đồng Nai",
        "BIÊN HÒA": "Tỉnh Đồng Nai",
        "Buôn Ma Thuột, Đắc Lắc": "Tỉnh Đắk Lắk",
        "Đắc Lắc": "Tỉnh Đắk Lắk",
        "Đắk Lắk": "Tỉnh Đắk Lắk",
        "Tỉnh Đắk Lắk": "Tỉnh Đắk Lắk",
        "Thành phố Hồ Chí Minh": "Thành phố Hồ Chí Minh",
        "
        "Q.TÂN BÌNH": "Thành phố Hồ Chí Minh",
        "BT.": "Thành phố Hồ Chí Minh",
        "QUẬN 12": "Thành phố Hồ Chí Minh",
        "QUẬN THỦ ĐỨC": "Thành phố Hồ Chí Minh",
        "Q BÌNH THẠNH": "Thành phố Hồ Chí Minh",
        "TPHCM .": "Thành phố Hồ Chí Minh",
        "PHƯỚC KIỂN - NHÀ BÈ": "Thành phố Hồ Chí Minh",
        "HÓC MÔN": "Thành phố Hồ Chí Minh",
        "Q. 1 TP.HCM": "Thành phố Hồ Chí Minh",
        "41-43 Trần Cao Vân Q. 3 TP.HCM": "Thành phố Hồ Chí Minh",
        "Q. Thủ Đức TP.HCM": "Thành phố Hồ Chí Minh",
        "Q.10 (VPGD)": "Thành phố Hồ Chí Minh",
        "phường An phú Đông": "Thành phố Hồ Chí Minh",
        "q10": "Thành phố Hồ Chí Minh",
        "Q6": "Thành phố Hồ Chí Minh",
        "Huyện Hóc Môn": "Thành phố Hồ Chí Minh",
        "Binh Thanh Dist": "Thành phố Hồ Chí Minh",
        "Bình Dương": "Tỉnh Bình Dương",
        "Bình dương": "Tỉnh Bình Dương",
        "Bình Dương.": "Tỉnh Bình Dương",
        "Tỉnh Bình Dương": "Tỉnh Bình Dương",
        "Thuận An, Bình Dương": "Tỉnh Bình Dương",
        "BÌNH DƯƠNG": "Tỉnh Bình Dương",
        "Thuận An, Bình Dương": "Tỉnh Bình Dương",
        "Bình Phước": "Tỉnh Bình Phước",
        "Bình phước": "Tỉnh Bình Phước",
        "Bình Định": "Tỉnh Bình Định",
        "Bạc Liêu": "Tỉnh Bạc Liêu",
        "Bắc Giang": "Tỉnh Bắc Giang",
        "Tỉnh Bắc Giang": "Tỉnh Bắc Giang",
        "Bắc Ninh": "Tỉnh Bắc Ninh",
        "Bến Tre": "Tỉnh Bến Tre",
        "Bến tre": "Tỉnh Bến Tre",
        "Cà Mau": "Tỉnh Cà Mau",
        "Long An": "Tỉnh Long An",
        "long an": "Tỉnh Long An",
        " Long An": "Tỉnh Long An",
        ", Tỉnh Long An.": "Tỉnh Long An",
        "Tỉnh Long An": "Tỉnh Long An",
        "T. Long An": "Tỉnh Long An",
        "Thanh Hóa": "Tỉnh Thanh Hóa",
        "Tỉnh Thanh Hóa": "Tỉnh Thanh Hóa",
        "TP. Thanh Hóa": "Tỉnh Thanh Hóa",
        "Thanh hóa": "Tỉnh Thanh Hóa",
        "Hải Phòng": "Thành phố Hải Phòng",
        "hải Phòng": "Thành phố Hải Phòng",
        "Thành phố Hải Phòng": "Thành phố Hải Phòng",
        "Vĩnh Long": "Tỉnh Vĩnh Long",
        "Vĩnh long": "Tỉnh Vĩnh Long",
        "Tỉnh Vĩnh Long": "Tỉnh Vĩnh Long",
        "Hà Nam": "Tỉnh Hà Nam",
        "tỉnh Hà Nam": "Tỉnh Hà Nam",
        "Tỉnh Hà Nam": "Tỉnh Hà Nam",
        "khu A khu đô thị mới Dương nội - Phường Dương Nội - Quận Hà Đông - Thành phố Hà Nội": "Thành phố Hà Nội",
        "Đà nẵng": "Thành phố Đà Nẵng",
        "TP. Đà Nẵng": "Thành phố Đà Nẵng",
        "  Thành Phố Đà Nẵng": "Thành phố Đà Nẵng",
        "Tp. Đà Nẵng": "Thành phố Đà Nẵng",
        "Thành phố Đà Nẵng": "Thành phố Đà Nẵng",
        "Tp Đà Nẵng": "Thành phố Đà Nẵng",
        "Quận Hải Châu": "Thành phố Đà Nẵng",
        "Hưng Yên": "Tỉnh Hưng Yên",
        "HƯng Yên": "Tỉnh Hưng Yên",
        "Tỉnh Hưng Yên": "Tỉnh Hưng Yên",
        "TP Hưng Yên MST: 0900450756": "Tỉnh Hưng Yên",
        "Khánh Hòa": "Tỉnh Khánh Hòa",
        "Tỉnh Khánh Hòa": "Tỉnh Khánh Hòa",
        "Kiên Giang": "Tỉnh Kiên Giang",
        "Rạch Giá, Kiên Giang": "Tỉnh Kiên Giang",
        "Tỉnh Kiên Giang": "Tỉnh Kiên Giang",
        "Bình Thuận": "Tỉnh Bình Thuận",
        "Bình thuận": "Tỉnh Bình Thuận",
        "Tỉnh Bình Thuận": "Tỉnh Bình Thuận",
        "Quảng Trị": "Tỉnh Quảng Trị",
        "tỉnh Quảng Trị": "Tỉnh Quảng Trị",
        "Tỉnh Đồng Tháp": "Tỉnh Đồng Tháp",
        "ĐỒNG THÁP": "Tỉnh Đồng Tháp",
        "Tỉnh Đồng Tháp": "Tỉnh Đồng Tháp",
        "Huế": "Tỉnh Thừa Thiên Huế",
        "Bạc Liêu": "Tỉnh Bạc Liêu",
        "Tỉnh Bạc Liêu": "Tỉnh Bạc Liêu",
        "Nghệ An": "Tỉnh Nghệ An",
        "tỉnh Nghệ An": "Tỉnh Nghệ An",
        "Tỉnh Nghệ An": "Tỉnh Nghệ An",
        "Bình Phước": "Tỉnh Bình Phước",
        "Bình phước": "Tỉnh Bình Phước",
        "Tỉnh Bình Phước": "Tỉnh Bình Phước",
        "TX. Đồng Xoài Tỉnh Bình Phước": "Tỉnh Bình Phước",
        "Cà Mau": "Tỉnh Cà Mau",
        "Thành Phố Cà Mau": "Tỉnh Cà Mau",
        "Ninh Thuận": "Tỉnh Ninh Thuận",
        "Tỉnh Ninh Thuận": "Tỉnh Ninh Thuận",
        "ninh thuận": "Tỉnh Ninh Thuận",
        "Hà Tĩnh": "Tỉnh Hà Tĩnh",
        "Tỉnh Hà Tĩnh": "Tỉnh Hà Tĩnh",
        "tdp Long Sơn- P Kỳ Long- TX Kỳ Anh- Hà Tĩnh": "Tỉnh Hà Tĩnh",
        "Tây Ninh": "Tỉnh Tây Ninh",
        "Tây ninh": "Tỉnh Tây Ninh",
        "Tỉnh Tây Ninh": "Tỉnh Tây Ninh",
        "Gia Lai": "Tỉnh Gia Lai",
        "Vĩnh Phúc": "Tỉnh Vĩnh Phúc",
        "Tỉnh Vĩnh Phúc": "Tỉnh Vĩnh Phúc",
        "tỉnh Vĩnh Phúc": "Tỉnh Vĩnh Phúc",
        "Thái Nguyên": "Tỉnh Thái Nguyên",
        "Tỉnh Thái Nguyên": "Tỉnh Thái Nguyên",
        "Sóc Trăng": "Tỉnh Sóc Trăng",
        "Tỉnh Sóc Trăng": "Tỉnh Sóc Trăng",
        "Đăk lăk": "Tỉnh Đắk Lắk",
        "Đăk Lăk": "Tỉnh Đắk Lắk",
        "Hậu Giang": "Tỉnh Hậu Giang",
        "Hậu giang": "Tỉnh Hậu Giang",
        "Tỉnh Hậu Giang": "Tỉnh Hậu Giang",
        "-": "",
        "Kon Tum": "Tỉnh Kon Tum",
        "Tỉnh Kon Tum": "Tỉnh Kon Tum",
        "Quảng Ngãi": "Tỉnh Quảng Ngãi",
        "Quảng ngãi": "Tỉnh Quảng Ngãi",
        "Tỉnh Quảng Ngãi": "Tỉnh Quảng Ngãi",
        "Phú Yên": "Tỉnh Phú Yên",
        "Tỉnh Phú Yên": "Tỉnh Phú Yên",
        "Tỉnh Trà Vinh": "Tỉnh Trà Vinh",
        "Quảng Bình": "Tỉnh Quảng Bình",
        "Quảng Nam": "Tỉnh Quảng Nam",
        "Quảng nam": "Tỉnh Quảng Nam",
        "Tỉnh Quảng Nam": "Tỉnh Quảng Nam",
        "Quãng nam": "Tỉnh Quảng Nam",
        "Quãng Nam": "Tỉnh Quảng Nam",
        "Ninh Bình": "Tỉnh Ninh Bình",
        "Tỉnh Ninh Bình": "Tỉnh Ninh Bình",
        "Phú Thọ": "Tỉnh Phú Thọ",
        "Phú Thọ": "Tỉnh Phú Thọ",
        "Tỉnh Phú Thọ": "Tỉnh Phú Thọ",
        "Quảng Ninh": "Tỉnh Quảng Ninh",
        "tỉnh Quảng Ninh": "Tỉnh Quảng Ninh",
        "Tỉnh Quảng Ninh": "Tỉnh Quảng Ninh",
        "Khu 3 - Phường Trưng Vương - Thành phố Uông Bí - Quảng Ninh.": "Tỉnh Quảng Ninh",
        "Tỉnh Đồng Nai": "Tỉnh Đồng Nai",
        "Đồng nai": "Tỉnh Đồng Nai",
        "Biên Hòa, Đồng Nai": "Tỉnh Đồng Nai",
        "Tỉnh Đồng Nai": "Tỉnh Đồng Nai",
        "Hải Dương": "Tỉnh Hải Dương",
        "Tỉnh Hải Dương": "Tỉnh Hải Dương",
        "TP. Hải Dương": "Tỉnh Hải Dương",
        "tỉnh Hải Dương": "Tỉnh Hải Dương",
        "TP Hải Dương": "Tỉnh Hải Dương",
        "Đắk Nông": "Tỉnh Đắk Nông",
        "Nam Định": "Tỉnh Nam Định",
        "tỉnh Nam Định": "Tỉnh Nam Định",
        "TP.Nam Định": "Tỉnh Nam Định",
        "Tuyên Quang": "Tỉnh Tuyên Quang",
        "Tỉnh Tuyên Quang": "Tỉnh Tuyên Quang",
        "Lào Cai": "Tỉnh Lào Cai",
        "Tỉnh Lào Cai": "Tỉnh Lào Cai",
        "Hòa Bình": "Tỉnh Sơn La",
        "Thái Bình": "Tỉnh Thái Bình",
        "TP. Thái Bình": "Tỉnh Thái Bình",
        "Thái Bình - MST 1000341682": "Tỉnh Thái Bình",
        "Tỉnh Bắc Kạn": "Tỉnh Bắc Kạn",
        "Tỉnh Lai Châu": "Tỉnh Lai Châu",
        "tỉnh Lai Châu": "Tỉnh Lai Châu",
        "": "",
        "": "",
        "": "",
        "": "",
        "": "",
        "": "",
        "": "",
        "": "",
    }
)

output_file = "../assets/modified_addressWithCity.csv"  # New file path
df.to_csv(output_file, index=False, encoding='utf-8')

# %%
import pandas as pd

# Step 1: Load the CSV file into a pandas DataFrame
input_file = "../assets/modified_addressWithCity.csv"  # Replace with your file path
df = pd.read_csv(input_file)

# Step 2: Define the city_area_mapping dictionary (as shown earlier)
city_area_mapping = {
    "Thành phố Hà Nội": 2, "Tỉnh Hà Giang": 2, "Tỉnh Cao Bằng": 2, 
    "Tỉnh Bắc Kạn": 2, "Tỉnh Tuyên Quang": 2, "Tỉnh Lào Cai": 2, 
    "Tỉnh Điện Biên": 2, "Tỉnh Lai Châu": 2, "Tỉnh Sơn La": 2, 
    "Tỉnh Yên Bái": 2, "Tỉnh Hoà Bình": 2, "Tỉnh Thái Nguyên": 2, 
    "Tỉnh Lạng Sơn": 2, "Tỉnh Quảng Ninh": 2, "Tỉnh Bắc Giang": 2, 
    "Tỉnh Phú Thọ": 2, "Tỉnh Vĩnh Phúc": 2, "Tỉnh Bắc Ninh": 2, 
    "Tỉnh Hải Dương": 2, "Thành phố Hải Phòng": 2, "Tỉnh Hưng Yên": 2, 
    "Tỉnh Thái Bình": 2, "Tỉnh Hà Nam": 2, "Tỉnh Nam Định": 2, 
    "Tỉnh Ninh Bình": 2, "Tỉnh Thanh Hóa": 3, "Tỉnh Nghệ An": 3, 
    "Tỉnh Hà Tĩnh": 3, "Tỉnh Quảng Bình": 3, "Tỉnh Quảng Trị": 3, 
    "Tỉnh Thừa Thiên Huế": 3, "Thành phố Đà Nẵng": 3, "Tỉnh Quảng Nam": 3, 
    "Tỉnh Quảng Ngãi": 3, "Tỉnh Bình Định": 3, "Tỉnh Phú Yên": 3, 
    "Tỉnh Khánh Hòa": 3, "Tỉnh Ninh Thuận": 3, "Tỉnh Bình Thuận": 3, 
    "Tỉnh Kon Tum": 4, "Tỉnh Gia Lai": 4, "Tỉnh Đắk Lắk": 4, 
    "Tỉnh Đắk Nông": 4, "Tỉnh Lâm Đồng": 4, "Tỉnh Bình Phước": 5, 
    "Tỉnh Tây Ninh": 5, "Tỉnh Bình Dương": 5, "Tỉnh Đồng Nai": 5, 
    "Tỉnh Bà Rịa - Vũng Tàu": 5, "Thành phố Hồ Chí Minh": 1, 
    "Tỉnh Long An": 6, "Tỉnh Tiền Giang": 6, "Tỉnh Bến Tre": 6, 
    "Tỉnh Trà Vinh": 6, "Tỉnh Vĩnh Long": 6, "Tỉnh Đồng Tháp": 6, 
    "Tỉnh An Giang": 6, "Tỉnh Kiên Giang": 6, "Thành phố Cần Thơ": 6, 
    "Tỉnh Hậu Giang": 6, "Tỉnh Sóc Trăng": 6, "Tỉnh Bạc Liêu": 6, 
    "Tỉnh Cà Mau": 6
}

def map_city_to_area(city_name):
    area_id = city_area_mapping.get(city_name)
    if area_id:
        return int(area_id)
    else:
        return None

df['area'] = df['city'].apply(map_city_to_area)

output_file = "../assets/modified_addressWithCity_with_area.csv"  # Replace with your file path
df.to_csv(output_file, index=False, encoding='utf-8')
